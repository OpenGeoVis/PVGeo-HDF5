# %%
import pvgeohdf
import vtki
import pandas as pd
import numpy as np

# %%
# Read a file using pvgeohdf
filename = '/Users/bane/Documents/OpenGeoVis/Data/data-testing/PVGeo-HDF5/epa/nc Files/EM_CN27_2016001.nc'
data = pvgeohdf.CMAQReader().Apply(filename)
data
# Out:
# (UniformGrid)0x1265cfd08

# %%
df = pd.DataFrame(data=data.cell_arrays)
df.describe()
# Out:
#                  NH3            NO2             NO            CO2  \
# count  295568.000000  295568.000000  295568.000000  295568.000000
# mean        0.004662       0.003941       0.054391      19.658045
# std         0.036628       0.032442       0.447694     147.161134
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         4.858178       2.717160      37.496811   12880.271484
#
#                   CO            SO2           PNH4          PNCOM      PH2O  \
# count  295568.000000  295568.000000  295568.000000  295568.000000  295568.0
# mean        0.324461       0.015598       0.012858       0.062441       0.0
# std         2.705193       0.129973       0.113577       0.590582       0.0
# min         0.000000       0.000000       0.000000       0.000000       0.0
# 25%         0.000000       0.000000       0.000000       0.000000       0.0
# 50%         0.000000       0.000000       0.000000       0.000000       0.0
# 75%         0.000000       0.000000       0.000000       0.000000       0.0
# max       200.222580      12.648001      11.000319      57.235874       0.0
#
#                  PNA      ...                 MEOH           MGLY       MVK  \
# count  295568.000000      ...        295568.000000  295568.000000  295568.0
# mean        0.003250      ...             0.000275       0.000025       0.0
# std         0.032832      ...             0.002748       0.000560       0.0
# min         0.000000      ...             0.000000       0.000000       0.0
# 25%         0.000000      ...             0.000000       0.000000       0.0
# 50%         0.000000      ...             0.000000       0.000000       0.0
# 75%         0.000000      ...             0.000000       0.000000       0.0
# max         3.611756      ...             0.201410       0.027514       0.0
#
#                NVOL           OLE1           OLE2          PHEN  \
# count  2.955680e+05  295568.000000  295568.000000  2.955680e+05
# mean   9.993137e-07       0.001553       0.002111  3.194991e-07
# std    6.567585e-05       0.015636       0.027649  3.732388e-05
# min    0.000000e+00       0.000000       0.000000  0.000000e+00
# 25%    0.000000e+00       0.000000       0.000000  0.000000e+00
# 50%    0.000000e+00       0.000000       0.000000  0.000000e+00
# 75%    0.000000e+00       0.000000       0.000000  0.000000e+00
# max    9.938276e-03       1.269686       3.114635  9.500111e-03
#
#                 PRD2           RCHO           TERP
# count  295568.000000  295568.000000  295568.000000
# mean        0.000098       0.000018       0.000011
# std         0.001417       0.000704       0.000429
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max         0.144410       0.074270       0.113021
#
# [8 rows x 54 columns]

# %%
data.set_active_scalar('NH3')

# %%
data.threshold(1e-1).wireframe().plot(notebook=True, rng=[0, 1])
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x10A255DA0>
